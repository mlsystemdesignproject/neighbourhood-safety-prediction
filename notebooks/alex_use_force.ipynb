# %%
import pandas as pd
import seaborn as sns
# openpyxl

# %%
# pip install openpyxl
df = pd.read_excel('./../data/MPS_actions/use_force/MPS Use of Force - FY22-23.xlsx')

# %%
df.head()
# Out:
#   IncidentDate IncidentTime Incident Location: Street/Highway  \
# 0   2022-04-01     15:00:00                                No
# 1   2022-04-01     16:00:00                               Yes
# 2   2022-04-01     15:50:00                                No
# 3   2022-04-01     12:30:00                               Yes
# 4   2022-04-01     15:53:00                               Yes
#
#   Incident Location: Public Transport Incident Location: Retail Premises  \
# 0                                  No                                 No
# 1                                  No                                 No
# 2                                 Yes                                 No
# 3                                  No                                 No
# 4                                  No                                 No
#
#   Incident Location: Open ground (e.g. park, car park, field)  \
# 0                                                 No
# ...

# %%
interesting = ["IncidentDate"] #, "IncidentTime"]
for inter in interesting:
    print('-------------')
    print(f'For {inter}:')
    print('-------------')
    print(*df[inter].unique(), sep='\n', end='\n---##---##---\n\n')
# Out:
# -------------
# For IncidentDate:
# -------------
# 2022-04-01
# 2022-04-02
# 2022-04-03
# 2022-04-04
# 2022-04-05
# 2022-04-06
# 2022-04-07
# 2022-04-08
# 2022-04-09
# 2022-04-10
# 2022-04-11
# 2022-04-12
# 2022-04-13
# 2022-04-14
# 2022-04-15
# 2022-04-16
# 2022-04-17
# 2022-04-18
# 2022-04-19
# 2022-04-20
# 2022-04-21
# 2022-04-22
# 2022-04-23
# 2022-04-24
# 2022-04-25
# 2022-04-26
# 2022-04-27
# 2022-04-28
# 2022-04-29
# 2022-04-30
# 2022-05-01
# 2022-05-02
# 2022-05-03
# 2022-05-04
# 2022-05-05
# 2022-05-06
# 2022-05-07
# 2022-05-08
# 2022-05-09
# 2022-05-10
# 2022-05-11
# 2022-05-12
# 2022-05-13
# 2022-05-14
# 2022-05-15
# 2022-05-16
# 2022-05-17
# 2022-05-18
# 2022-05-19
# 2022-05-20
# 2022-05-21
# 2022-05-22
# 2022-05-23
# 2022-05-24
# 2022-05-25
# 2022-05-26
# 2022-05-27
# 2022-05-28
# 2022-05-29
# 2022-05-30
# 2022-05-31
# 2022-06-01
# 2022-06-02
# 2022-06-03
# 2022-06-04
# 2022-06-05
# 2022-06-06
# 2022-06-07
# 2022-06-08
# 2022-06-09
# 2022-06-10
# 2022-06-11
# ...

# %% [markdown]
# PrimaryConduct
# AssaultedBySubject
# ThreatenedWithWeapon
# AssaultedWithWeapon

# %%
interesting = ["PrimaryConduct", "AssaultedBySubject", "ThreatenedWithWeapon", "AssaultedWithWeapon"]
for inter in interesting:
    print('-------------')
    print(f'For {inter}:')
    print('-------------')
    print(*df[inter].unique(), sep='\n', end='\n---##---##---\n\n')
# Out:
# -------------
# For PrimaryConduct:
# -------------
# Aggressive resistance
# Compliant
# Active resistance
# Verbal resistance/gestures
# Passive resistance
# Serious or aggravated resistance
# ---##---##---
#
# -------------
# For AssaultedBySubject:
# -------------
# No
# Yes
# ---##---##---
#
# -------------
# For ThreatenedWithWeapon:
# -------------
# nan
# Bladed weapon/object
# Bladed weapon/object, Pointed weapon/object
# Blunt weapon/object
# Pointed weapon/object
# Firearm, Blunt weapon/object
# Other
# Missile/object thrown, Blunt weapon/object, Other
# Missile/object thrown
# Firearm
# Pointed weapon/object, Blunt weapon/object
# Bladed weapon/object, Pointed weapon/object, Missile/object thrown
# Bladed weapon/object, Pointed weapon/object, Missile/object thrown, Blunt weapon/object
# Firearm, Bladed weapon/object
# Bladed weapon/object, Pointed weapon/object, Missile/object thrown, Blunt weapon/object, Other
# Pointed weapon/object, Missile/object thrown
# ...

# %%
interesting = ['MainDuty', 'TrainedCED', 'CarryingCED', "Tactic 1", "Effective 1", "Tactic 2", "Effective 2", 'CED Used']
for inter in interesting:
    print('-------------')
    print(f'For {inter}:')
    print('-------------')
    print(*df[inter].unique(), sep='\n', end='\n---##---##---\n\n')
# Out:
# -------------
# For MainDuty:
# -------------
# Mobile patrol
# ARV
# Foot patrol
# Roads policing
# Custody
# PSU/Public order
# Other
# CID
# Off duty
# Dog handler duty
# AFO
# Mounted section duties
# CTSFO
# Surveillance
# ---##---##---
#
# -------------
# For TrainedCED:
# -------------
# No
# Yes
# ---##---##---
#
# -------------
# For CarryingCED:
# -------------
# nan
# Yes
# No
# ---##---##---
#
# -------------
# For Tactic 1:
# -------------
# Ground restraint
# Compliant handcuffing
# Non-compliant handcuffing
# Tactical communications
# Other/improvised
# Unarmed skills (including pressure points, strikes, restraints and take-downs)
# CED (Taser) drawn
# Limb/body restraints
# Baton drawn
# CED (Taser) red-dotted
# Firearm aimed
# Dog deployed
# CED (Taser) aimed
# CED (Taser) fired
# Irritant spray - PAVA drawn
# Irritant spray - PAVA used
# Dog bite
# Baton used
# Spit guard
# AEP aimed
# Irritant spray - CS drawn
# Shield
# Irritant spray - CS used
# ...

# %%
for col in df.columns:
    print(col)
# Out:
# IncidentDate
# IncidentTime
# Incident Location: Street/Highway
# Incident Location: Public Transport
# Incident Location: Retail Premises
# Incident Location: Open ground (e.g. park, car park, field)
# Incident Location: Licensed Premises
# Incident Location: Sports or Event Stadia
# Incident Location: Hospital/A&E (non-mental-health setting)
# Incident Location: Mental Health Setting
# Incident Location: Police vehicle with prisoner handling cage
# Incident Location: Police vehicle without prisoner handling cage
# Incident Location: Dwelling
# Incident Location: Police station (excluding custody block)
# Incident Location: Custody Block
# Incident Location: Ambulance
# Incident Location: Other
# Borough
# PrimaryConduct
# AssaultedBySubject
# ThreatenedWithWeapon
# AssaultedWithWeapon
# Impact Factor: Possesion of a weapon
# Impact Factor: Alcohol
# Impact Factor: Drugs
# Impact Factor: Mental Health
# Impact Factor: Prior Knowledge
# Impact Factor: Size/Gender/Build
# ...
